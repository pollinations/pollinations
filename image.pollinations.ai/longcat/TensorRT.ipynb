# %%
# !pip install nvidia-pyindex
# !pip install tensorrt-cu11
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
from diffusers import LongCatImagePipeline

pipe = LongCatImagePipeline.from_pretrained(
    "meituan-longcat/LongCat-Image",
    torch_dtype=torch.float16,
    
).to("cuda")

print(pipe.components)

# TEXT_SEQ = 77
# EMB = pipe.text_encoder.config.hidden_size

# def export_unet(name, h, w):
#     latent = torch.randn(1, 4, h, w, device="cuda", dtype=torch.float16)
#     timestep = torch.tensor([1], device="cuda", dtype=torch.int64)
#     text = torch.randn(1, TEXT_SEQ, EMB, device="cuda", dtype=torch.float16)

#     torch.onnx.export(
#         pipe.unet,
#         (latent, timestep, text),
#         f"unet_{name}.onnx",
#         input_names=["latent", "timestep", "encoder_hidden_states"],
#         output_names=["noise_pred"],
#         opset_version=17,
#         do_constant_folding=True
#     )

# export_unet("square", 96, 96)
# export_unet("landscape", 96, 168)
# export_unet("portrait", 168, 96)
# Out:
# Keyword arguments {'safety_checker': None} are not expected by LongCatImagePipeline and will be ignored.
# ...
# Loading pipeline components...: 100%|██████████| 6/6 [00:07<00:00,  1.21s/it]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[2], line 8
#       1 import torch
#       2 from diffusers import LongCatImagePipeline
#       4 pipe = LongCatImagePipeline.from_pretrained(
#       5     "meituan-longcat/LongCat-Image",
#       6     torch_dtype=torch.float16,
#       7     safety_checker=None
# ----> 8 ).to("cuda")
#      10 print(pipe.components)
#      12 # TEXT_SEQ = 77
#      13 # EMB = pipe.text_encoder.config.hidden_size
#      14
#    (...)
#      31 # export_unet("landscape", 96, 168)
#      32 # export_unet("portrait", 168, 96)
#
# ...
